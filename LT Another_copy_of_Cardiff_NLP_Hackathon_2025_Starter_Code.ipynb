# %% [markdown]
# ## Cardiff NLP Hackathon 2025 - Starter Code
#
# Welcome to Cardiff NLP's second hackathon! Below is some code to get started on the AMPLYFI API and look at some data.
#
# ====================
#
# Note: the API is a real time resource so extra points to projects that can treat it as a continual data stream rather than a one-off data source!
#
# Another thing to note about this is that it will affect Amplyfi's servers if you download a silly amount of data. We ask that you only request 100 results per request, but if you have the data you need, try to download it or store it as a variable rather than requesting the exact same data over and over again.

# %%
# Import some libraries

import requests
import json
import nltk
import re
import pandas as pd
from collections import defaultdict

from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %% [markdown]
# Amplyfi have provided some limits and explanations of what you can query the API for below:
#
# `query_text` anything
#
# `result_size` <=100
#
# `include_highlights` boolean (if True, you get sentences matching keyphrases in the query)
#
# `include_smart_tags` boolean (if True, you get back metadata from our "smart" market intel classifiers - signals and industries)
#
# `ai_answer` can only accept "basic", this will take the 5 most relevant docs and answer the query_text based on them

# %%
# API endpoint from the newly deployed service

API_URL = "https://zfgp45ih7i.execute-api.eu-west-1.amazonaws.com/sandbox/api/search"
API_KEY = "XYZ38746G38B7RB46GBER"

headers = {
    "Content-Type": "application/json",
    "x-api-key": API_KEY
}

# Edit the below to get different data
payload = {
  "query_text": "what is happening with riots in Los Angeles?",
  "result_size": 100,
  "include_highlights":True,
  "include_smart_tags":True,

}

response = requests.post(API_URL, headers=headers, data=json.dumps(payload))
json_response = response.json()

json_response
# Out:
# {'results': [{'id': 'DL-91a8a3bb8d9240f9471bcd781b9f3bf3',
#    'title': 'Los Angeles riots',
#    'url': 'https://my-h5news.app.xinhuanet.com/h5/specialTopic/index.html?articleId=024a90db17da4691868e51bd10420f78',
#    'summary': 'Los Angeles police and the National Guard clashed with protesters in downtown Los Angeles, California. Roads were blocked, cars were burned, law enforcement used tear gas and lightning. riots in Angel City are spreading to other immigrant-populated cities such as New York City.',
#    'score': 395.3676,
#    'timestamp': '2025-06-10T05:22:00+00:00',
#    'smart_tags': {'industries': ['Media']},
#    'highlights': ['unrest, the National Guard and Los Angeles police clashed with protesters, and riots in Angel City are spreading to other immigrant-populated cities such as New York City.',
#     'Los Angeles police and the National Guard clashed violently with protesters in Los Angeles on August 8, causing chaos in downtown Los Angeles, the second-largest city in the United States, known as the City of Angels.',
#     'US President Donald Trump and the Democratic governor of the United States accused each other of protesting the conflict in Los Angeles on the 8th.']},
#   {'id': 'DL-e6bd910606666aedf96a1aefc60118bd',
#    'title': 'Los Angeles ICE Riots and the Constitution',
#    'url': 'https://canadafreepress.com/print_friendly/los-angeles-ice-riots-and-the-constitution',
#    'summary': 'Congress and President Trump have every constitutional authority to do so Cover Story | CFP Comments | Subscribe | Email Us What we are witnessing with the ICE Riots in Los Angeles this weekend is a full-blown, left-wing, anti-American riot. False pretense that Los Angeles is immune from federal immigration law. There is no constitutional basis for sanctuary cities.',
#    'score': 266.26337,
#    'timestamp': '2025-06-09T19:30:16+00:00',
#    'smart_tags': {'industries': ['Legal', 'Media']},
#    'highlights': ['What we are witnessing with the ICE Riots in Los Angeles this weekend is a full-blown, left-wing, anti-American riot--an insurrection disguised as activism.',
#     'False pretense that Los Angeles is a “sanctuary city,” immune from federal immigration law\nThe mainstream media and progressive commie Democrats who claim they love the Constitution when they think it suits their purposes have been calling the ICE Riots',
#     'The cameras pointed at the ICE Riots in Los Angeles have provided us a clear view of what is happening, and what we are seeing are violent demonstrations--violent riots--on the streets of Los Angeles.']},
#   {'id': 'DL-6b228b744d99d48c3ca028b53a281995',
#    'title': 'After Trump deploys National Guard, Marines on standby as Los Angeles protests enter fourth day',
#    'url': 'https://www.cbsnews.com/philadelphia/video/after-trump-deploys-national-guard-marines-on-standby-as-los-angeles-protests-enter-fourth-day/',
#    'summary': 'After Trump deploys National Guard, Marines on standby as Los Angeles protests enter fourth day Clashes between protestors and law enforcement turned violent in Los Angeles as demonstrations against ICE raids ramped up over the weekend. President Trump deployed the National Guard to the area, and the military confirmed to CBS News that hundreds of active duty Marines are now on standby to respond to the unrest.',
#    'score': 250.97192,
#    'timestamp': '2025-06-09T07:15:00',
#    'smart_tags': {'industries': ['Aerospace and Defense']},
#    'highlights': ['After Trump deploys National Guard, Marines on standby as Los Angeles protests enter fourth day Clashes between protestors and law enforcement turned violent in Los Angeles as demonstrations against ICE raids ramped up over the weekend.']},
#   {'id': 'DL-f8d6b234770f12e883b639a56015ad4f',
#    'title': 'Protests Against Immigration Officers Grow in Los Angeles Over Riots',
#    'url': 'https://www.elheraldo.co/mundo/2025/06/07/protestas-contra-agentes-de-inmigracion-crece-en-los-angeles-por-redadas/',
#    'summary': 'Dozens of agents with tactical equipment raided a company in Paramount City this morning, where activists report at least 65 workers have been arrested. For more than two hours, the police beat the demonstrators with tear gas. The slogans of “outside ICE” were repeated throughout the day, which recorded more chaotic scenes than this Friday.',
#    'score': 244.16472,
#    'timestamp': '2025-06-07T21:36:06+00:00',
#    'highlights': ['Read also: Pilot of Pablo Escobar shared details of his life with drug dealer Incommunicado As protests unfolded in the streets of Los Angeles this Saturday, federal authorities denied American lawyers and congressmen access to the ICE detention center',
#     'The Trump administration defends itself But the White House has defended itself and tried to counter the narrative by seeking to hold the democratic leaders in Los Angeles and California accountable.',
#     'In this regard, the Undersecretary of the Department of National Security, Tricia McLaughlin, accused the demonstrators of assaulting ICE officers, painting tires, and destroying federal properties with graffiti.']},
#   {'id': 'DL-a9e662c92672ade6eba30625692f9696',
#    'title': 'Multiple Waymo vehicles set on fire during Los Angeles riots',
#    'url': 'https://www.the-express.com/news/us-news/174269/los-angeles-waymo-vehicles-fire-anti-ice-activists-clash-police-paramount',
#    'summary': 'Scenes in Los Angeles become increasingly chaotic with images and footage showing vehicles on fire. ICE protests escalated into clashes with police involving tear gas and flash bangs. On Sunday, the National Guard was deployed in the city following orders from President Trump.',
#    'score': 242.12503,
#    'timestamp': '2025-06-09T08:40:00+00:00',
#    'smart_tags': {'industries': ['Aerospace and Defense']},
#    'highlights': ['Scenes in Los Angeles have become increasingly chaotic, with images and footage showing multiple vehicles on fire.\nAs immigration enforcement activities ramp up in Los Angeles, chaos has ensued across the Californian city.',
#     'Trump warns we are going to have troops everywhere after ICE protests\nSome scenes coming out of Los Angeles look apocalyptic, as fires break out and large groups of people take to the streets to push back on law enforcement.',
#     "These recent incidents of immigration-related arrests in Los Angeles align with the Trump administration's broader objectives to enhance the scale of deportations across the country."]},
#   {'id': 'DL-8e28d014a01560ee5e70f94578f4bd35',
#    'title': 'Ogden residents demonstrate solidarity with Los Angeles protesters',
#    'url': 'https://www.fox13now.com/news/politics/ogden-residents-demonstrate-solidarity-with-los-angeles-protesters',
#    'summary': 'About 30-40 people in Ogden protested actions by the Trump administration. They stood in solidarity with those in Los Angeles and across the country. "I love our country and I love our constitution and our democracy, and I’m here to protect and defend it," says Lynnette Wilkins.',
#    'score': 241.04758,
#    'timestamp': '2025-06-09T22:04:36',
#    'smart_tags': {'industries': ['Media']},
#    'highlights': ['OGDEN, Utah — About 30-40 people in Ogden protested actions by the Trump administration Monday night. They stood in solidarity with those in Los Angeles and across the country, hoping to get their message out, loud and clear.',
#     'WATCH: Utahns show up to stand in solidarity with Los Angeles protests\nUtahns show up to stand in solidarity with Los Angeles protests\nPeople gathered to show their support for those who might feel targeted right now.',
#     '"I need my country to be a safe place for immigrants and for peaceful protests,” the anonymous demonstrator said.\nThis comes as people in Los Angeles are protesting ICE.']},
#   {'id': 'DL-41bcf741298bc3f21a6d4f4773747b71',
#    'title': 'The Masque and Trump Controversy and the Los Angeles Riots',
#    'url': 'https://radiosputnik.ru/20250609/1978581634.html',
#    'summary': 'We are discussing on the air of radio Sputnik. You can listen to the first part of the program here. There is no telegram channel like ours.',
#    'score': 239.28215,
#    'timestamp': '2025-06-09T16:13:00+00:00',
#    'smart_tags': {'industries': ['Media']},
#    'highlights': ['Masque and Trump quarrels and protests in Los Angeles Read in Zen Is Ilon Musk capable of breaking the US bipartisan system? Will he become the new face of the Republicans? What will the protests in Los Angeles lead to?']},
#   {'id': 'DL-d5a6bfdf83fd122632c7c16ed2b17456',
#    'title': 'Protests against riots in Los Angeles on the rise',
#    'url': 'https://www.jornada.com.mx/2025/06/09/mundo/024n1mun?partner=rss',
#    'summary': 'National Guard troops confronted thousands of demonstrators in downtown Los Angeles yesterday and threw tear gas at a growing crowd. The mobilization was suppressed in front of the Los Angeles Metropolitan Detention Center while a group of people demanded elements of this federal force, equipped with anti-riot shields: ICE, out of Los Angeles!, in reference to the Immigration and Customs Control Service.',
#    'score': 233.62392,
#    'timestamp': '2025-06-09T05:00:00',
#    'smart_tags': {'industries': ['Media']},
#    'highlights': ['Photo Afp Ap, Afp and Reuters Periódico La Jornada Monday 9 June 2025, p. 24 Los Angeles. , National Guard troops confronted thousands of demonstrators in downtown Los Angeles yesterday and threw tear gas at a growing crowd that gathered in front of a',
#     'The Los Angeles Police Department reported that social dissatisfaction rallies reached Highway 101, where demonstrators with Mexican flags and banners reading: Plenary Rights for All Migrants closed both ways at 3:45 p.m. local time; later, the California',
#     'Highway Patrol cleared the highway, the Los Angeles Times reported on its website.']},
#   {'id': 'DL-11225404e9551bb065b4094eee403a4b',
#    'title': 'Mask sided with Trump over Los Angeles riots after recent controversy',
#    'url': 'https://sud.ua/ru/news/abroad/333140-mask-posle-nedavnego-spora-stal-na-storonu-trampa-v-voprose-podavleniya-besporyadkov-v-los-andzhelese',
#    'summary': "Elon Musk endorsed Donald Trump's actions against migrant protests in Los Angeles. UA American billionaire Ilon Musk called on California Governor and Los Angeles Mayor Karen Bass to apologize to the city's residents for the clashes.",
#    'score': 232.46715,
#    'timestamp': '2025-06-09T00:00:00',
#    'smart_tags': {'industries': ['Media']},
#    'highlights': ['President Donald Trump, reacting to the situation with riots in Los Angeles.',
#     'The Trump message reads: “Once upon a time, the great American city of Los Angeles was captured and occupied by illegal aliens and criminals.',
#     '“The order will be restored, the illegals will be expelled, and Los Angeles will be released. Thank you for your attention on this issue,” Trump added. Recall, between Donald Trump and Ilon Musk there was a public quarrel.']},
#   {'id': 'DL-c3743d03de4268780147088e303f8f94',
#    'title': 'Los Angeles protests against migration policy.',
#    'url': 'https://24tv.ua/los-andzheles-protesti-vse-shho-vidomo-pro-mitingi-proti-migratsiynoyi-politiki_n2842200/amp',
#    'summary': "Peaceful protests have escalated into large-scale battles using tear gas and cluster munitions. The President sent National Guard fighters to Los Angeles to stop protests against immigration policy. Everything that's known about the situation in Los Angeles as it stands now has been documented by Channel 24.",
#    'score': 226.02151,
#    'timestamp': None,
#    'highlights': ['In the U.S. city of Los Angeles, on June 6, protests broke out in response to the actions of the U.S. Immigration and Customs Service, which is arresting illegal immigrants under the orders of Donald Trump.',
#     'Peaceful protests have escalated into large-scale battles using tear gas and cluster munitions. The President of the United States even sent National Guard fighters to Los Angeles to stop protests against immigration policy.',
#     "The black protest in the U.S. is not going smoothly. Everything that's known about the situation in Los Angeles as it stands right now has been documented by Channel 24. See also After the Trump Affair: Can Musk Start a Democratic Support Campaign?"]},
#   {'id': 'DL-d464615c173647f9613c4c251a76e8e9',
#    'title': 'United States police shoot rubber bullet at Australian reporter during riots in Los Angeles',
#    'url': 'https://www.huffingtonpost.es/global/un-policia-estados-unidos-dispara-pelota-goma-reportera-australiana-disturbios-angeles.html',
#    'summary': "Lauren Tomasi was reporting on the riots in Los Angeles over Donald Trump's anti-migration policies. One of the city's policemen shot her and her camera directly and shot them with a rubber bullet. The U.S. president has ordered the deployment of 2,000 National Guard troops. For his part, Governor Gavin Newsom announced that he will sue the government.",
#    'score': 223.27592,
#    'timestamp': '2025-06-09T13:13:21',
#    'smart_tags': {'industries': ['Aerospace and Defense', 'Media']},
#    'highlights': ["Lauren Tomasi, Australia's Nine News U.S. correspondent, was reporting on the riots in Los Angeles over Donald Trump's anti-migration policies when one of the city's policemen shot her and her camera directly and shot them with a rubber bullet.",
#     "The U.S. president has ordered the deployment of 2,000 National Guard troops in Los Angeles to quell protests against his government's massive immigration raids in the county.",
#     'The deployment of troops has generated criticism from both the governor of California and the mayor of Los Angeles, who Trump\'s well-known frontier czar, Tom Homan, has threatened to stop "if they exceed" their powers.']},
#   {'id': 'DL-e45cab34f36bf649687b9e460eb0c82e',
#    'title': 'Los Angeles protests against immigration policy',
#    'url': 'https://24tv.ua/ru/los-andzheles-protesty-protiv-migracionnoj-politiki-vse-chto_n2842238/amp',
#    'summary': 'Peaceful rallies turned into large-scale clashes using tear gas and light-noise grenades. The U.S. President even sent National Guard fighters to Los Angeles to stop protests against immigration policies.',
#    'score': 222.36618,
#    'timestamp': None,
#    'highlights': ['President even sent National Guard fighters to Los Angeles to stop protests against immigration policies. The next protest in the United States is not going quietly.',
#     'All that is known about the situation in Los Angeles as of now, Channel 24 collected in the material. See also After the Trump Affair: Can Musk Start a Campaign to Support Democrats']},
#   {'id': 'DL-554cf1f86d929744e72f5f079a83cb73',
#    'title': 'Anti-ICE Riot in Los Angeles',
#    'url': 'https://hotair.com/john-s-2/2025/06/07/anti-ice-riot-in-los-angeles-n3803573',
#    'summary': 'A riot broke out in Paramount where ICE agents were looking to arrest a few dozen criminal illegal aliens. The confrontation escalated into a fiery and tumultuous clash. At least one protester was injured, witnesses reported.',
#    'score': 221.92372,
#    'timestamp': '2025-06-08T00:15:24+00:00',
#    'smart_tags': {'industries': ['Media']},
#    'highlights': ['There were similar ICE raids yesterday and those protests also got out of hand.\nLOS ANGELES — Federal law enforcement officials faced off with violent anti-ICE rioters June 6.',
#     'On Saturday, Trump administration officials blasted the city’s response to the Friday operations by Immigration and Customs Enforcement, criticizing Los Angeles officials for not helping the federal agents, as well as blaming Democrats for the unrest.',
#     'Stephen Miller, the White House deputy chief of staff, said on social media on Saturday that the protests on Friday were “an insurrection against the laws and sovereignty of the United States.”\nSo there you have it.']},
#   {'id': 'DL-122648f2e647d07dee07b7758bb06044',
#    'title': 'Tens of migrants arrested in riots in Los Angeles',
#    'url': 'https://ariesonline.com.ar/contenido/163163/decenas-de-migrantes-detenidos-en-redadas-en-los-angeles',
#    'summary': 'The U.S. Immigration and Customs Service (ICE) conducted a series of immigration raids in Los Angeles. At least three major migration operations were reported by immigrant advocates in predominantly Hispanic downtown areas. "Migration alert is all over Los Angeles this Friday," warns text messages distributed among the community.',
#    'score': 217.08238,
#    'timestamp': '2025-06-07T12:26:00',
#    'highlights': ['Los Angeles Mayor Karen Bass said in a statement that she is "deeply outraged" by the operatives. We will not tolerate this," added the Democrat, who said she was in contact with immigrants\' advocacy organizations to support the affected community.',
#     'A demonstration is called for the evening of this Friday in front of the immigration prison in downtown Los Angeles a few meters from the Alcaldía headquarters.']},
#   {'id': 'DL-c20e0420b2da1139a5e89d73df4c3d36',
#    'title': 'Migrants in Los Angeles protest ICE raids',
#    'url': 'https://mvsnoticias.com/entrevistas/2025/6/9/migrantes-en-los-angeles-protestan-contra-redadas-de-ice-696284.html',
#    'summary': 'Dayanis López-Reyes, a journalist in Los Angeles, spoke about the protests of migrants. The streets of downtown Los Angeles are bursting with indignation. For the fourth consecutive day, thousands of migrants protest against ICE raids.',
#    'score': 214.7866,
#    'timestamp': '2025-06-09T23:18:31+00:00',
#    'smart_tags': {'industries': ['Hospitality and Travel']},
#    'highlights': ['In an interview with Luis Ochoa and Roxana Aguilar in the absence of Pamela Cerdeira, for MVS Noticias, Dayanis López-Reyes, a journalist in Los Angeles, California, spoke about the protests of migrants in Los Angeles against ICE raids and arrests.',
#     'The streets of downtown Los Angeles are bursting with indignation. For the fourth consecutive day, thousands of migrants - mostly Mexicans and Central Americans - protest against raids by the Immigration and Customs Control Service (ICE).',
#     'You might be interested in ‘This didn’t come as a surprise to Trump’: What’s Behind Riots and Riots in Los Angeles Protesters’ Voice From the heart of downtown LA, López-Reyes described: "I saw grandmothers with grandchildren in arms and young people']},
#   {'id': 'DL-abfbd36bddc0306f9614105b3abe0069',
#    'title': "Los Angeles Trump protests | I won't let you hide in demonstrations in California",
#    'url': 'https://www.zazoom.it/2025-06-08/proteste-los-angeles-trump-non-permettero-maschere-nelle-manifestazioni-in-california/17149156/',
#    'summary': 'Los Angeles protests shed light on a climate of growing tension, especially after federal arrests. In an already turbulent environment, demonstrations have become loud and clear. The federal immigration authorities, in the last few days, have arrested dozens of people.',
#    'score': 205.87625,
#    'timestamp': '2025-06-08T15:56:01',
#    'smart_tags': {'industries': ['Media']},
#    'highlights': ["Los Angeles Trump protests | I won't let you hide in demonstrations in California Recent protests in Los Angeles have shed light on a climate of growing tension, especially after federal arrests.",
#     'The federal immigration authorities, in the last few days, have arrested dozens of people all over Los Angeles, venting their anger at the protesters. ⇑ Read on Tgcom24.mediaset.it © Tgcom24.mediaset.it - Los Angeles protests, Trump: "I will not allow',
#     'masks in demonstrations in California" This news talks about: Angeles Trump protests I will allow protests in Los Angeles against anti-migrant raids: clashes with the police -- Tensions are erupting in Los Angeles, where protesters and law enforcement']},
#   {'id': 'DL-5cc2e2539baa44fbb7488f647590d538',
#    'title': 'Chaos intensifies: Riots in Los Angeles lead to looting (PHOTO)',
#    'url': 'https://lapatilla.com/2025/06/09/se-intensifica-el-caos-los-disturbios-en-los-angeles-derivan-en-saqueos-fotos/',
#    'summary': "Violent anti-immigration riots that have plagued downtown Los Angeles continued to rise. a video showed mobs of robbers robbing Foot Locker and T-Mobile stores in the dark on Sunday night. Subscribe to Venezuela's Most Important Newsletter Disturbing images show criminals, many of them masked, breaking the windows of the South Broadway cellular phone store and disappearing inside before emerging with their arms loaded with merchandise.",
#    'score': 204.24573,
#    'timestamp': '2025-06-09T22:46:00+00:00',
#    'smart_tags': {'industries': ['Media']},
#    'highlights': ['Violent anti-immigration riots that have plagued downtown Los Angeles since the weekend continued to rise, and a video showed mobs of robbers robbing Foot Locker and T-Mobile stores in the dark on Sunday night. By New York Post Join the club now!']},
#   {'id': 'DL-526e13f1b9c1b8034a54ce9c2cbdbdfa',
#    'title': "Mexico's Prime Minister makes recommendations to Mexicans after 42 arrests in Los Angeles riots",
#    'url': 'https://laopinion.com/2025/06/09/canciller-de-mexico-ofrece-recomendaciones-a-mexicanos-tras-detencion-de-42-en-redadas-de-los-angeles/',
#    'summary': 'Juan Ramón de la Fuente issued a series of recommendations for Mexicans in the United States who might be arrested during raids in Los Angeles. The Mexican Chancellor said that the entire consular network is alerted to be strengthening the information that our fellow nationals must have at this time.',
#    'score': 202.82141,
#    'timestamp': '2025-06-09T17:58:33+00:00',
#    'smart_tags': {'signals': ['Leadership Mention'], 'industries': ['Legal']},
#    'highlights': ['Continue reading: · Los Angeles witnesses second day of protests and clashes over ICE raids · DHS condemns protests over ICE raids in Los Angeles with serious charges · SEIU president injured and detained during ICE raids in Los Angeles · ICE raids injure',
#     'Los Angeles and cause protests and arrests']},
#   {'id': 'DL-625ad55d47e89511ac90bf9176978b16',
#    'title': 'Photos: Riots in Los Angeles after immigration raids',
#    'url': 'https://www.telemundo51.com/noticias/eeuu/fotos-disturbios-en-los-angeles-tras-redadas-de-inmigracion/2665058/',
#    'summary': 'On Saturday, protesters and federal and local law enforcement officers clashed after immigration operations were conducted throughout the Los Angeles area. A car was set on fire at an intersection in Compton during a demonstration against the Immigration and Customs Control Service (ICE). On Friday, demonstrators blocked a street with shopping carts and a garbage can.',
#    'score': 198.22769,
#    'timestamp': '2025-06-08T03:38:53',
#    'smart_tags': {'industries': ['Media']},
#    'highlights': ['On Saturday, protesters and federal and local law enforcement officers clashed after immigration operations were conducted throughout the Los Angeles area.',
#     'A car was set on fire at an intersection in Compton on Saturday during a demonstration against the Immigration and Customs Control Service (ICE). Florida News 24/7 on Telemundo 51.']},
#   {'id': 'DL-b0b5d87dee94ebadf9f18e9b7e7c3fe6',
#    'title': 'Migratory networks against Hispanics in Los Angeles spark protests and clashes',
#    'url': 'https://www.eluniversal.com.mx/mundo/fotos-redas-migratorias-contra-hispanos-en-los-angeles-desatan-protestas-y-enfrentamientos/',
#    'summary': 'Several dozen people were arrested in immigration and Customs Control raids this Friday in various Los Angeles locations. Tens of people protest outside a federal building after federal immigration authorities conducted a migration operation in Los Angeles on Friday, June 6, 2025. AP 11 Mexican citizens arrested during the raid have so far been identified, according to the Los Angeles Times.',
#    'score': 197.99893,
#    'timestamp': '2025-06-07T17:27:20',
#    'smart_tags': {'industries': ['Media']},
#    'highlights': ['Several dozen people were arrested in Immigration and Customs Control (ICE) raids this Friday in various Los Angeles locations that sparked protests and clashes between federal agents and demonstrators in downtown Los Angeles.',
#     'A demonstrator protests against riot police in Los Angeles after federal immigration authorities arrested him on Friday, June 6, 2025.',
#     'A demonstrator is beaten by police during a protest in Los Angeles against operations carried out by federal immigration authorities, Friday, June 6, 2025.']},
#   {'id': 'DL-86d2cb43e57c412ef3753104e8eef8ab',
#    'title': 'Riots in Los Angeles Raids by masked and armed officials against migrants trigger protests',
#    'url': 'https://www.stuttgarter-nachrichten.de/inhalt.aufruhr-in-los-angeles-razzien-maskierter-und-bewaffneter-beamter-gegen-migranten-loesen-proteste-aus.e47b08a1-aa02-4356-90a5-793cfc7d41c6.html',
#    'summary': 'Violent riots broke out in Los Angeles. Raids by masked and armed officials against migrants triggered the protests. In Los Angeles, raids by masked and armed officials have sparked angry protests against migrants. On Friday (local time), angry demonstrators chased an Immigration Department (ICE) convoy in the US metropolitan area and threw eggs at the officers, who then drove the crowd apart with grenades. Mayor Karen Bass stated that the martial actions of the officials are causing "terror in our communities".',
#    'score': 196.10043,
#    'timestamp': '2025-06-07T13:56:53+00:00',
#    'smart_tags': {'industries': ['Media']},
#    'highlights': []},
#   {'id': 'DL-68bdffa64126220cbbc75b757ce9643e',
#    'title': 'TV reporter shot live on air during Los Angeles riots as report abruptly cut',
#    'url': 'https://www.express.co.uk/showbiz/tv-radio/2066118/tv-reporter-shot-live-LA-riots',
#    'summary': 'Australian reporter Lauren Tomasi was shot at by police as she provided updates live from the LA riots in Los Angeles. The live broadcast was suddenly cut short in order to allow her and cameraman to move to safety. There were also fears for Good Morning Britain presenter Noel Phillips, who had to cut a broadcast short due to what "sounded like gunshots"',
#    'score': 195.84657,
#    'timestamp': '2025-06-09T09:06:00+00:00',
#    'smart_tags': {'industries': ['Media']},
#    'highlights': []},
#   {'id': 'DL-3a1cc0566c6faae57273b9bffbfe324a',
#    'title': 'VIDEOD ⟩ Reporter hit by rubber bullet during live broadcast of Los Angeles riots',
#    'url': 'https://elu24.postimees.ee/8265385/videod-reporter-sai-los-angelese-massu-otseulekande-ajal-kummikuuliga-pihta',
#    'summary': 'According to the Australian channel 9News, Tomas and his cameramen were not seriously injured in the incident. According to Reuters, they are "secured and will continue their important work in reporting events".',
#    'score': 195.84657,
#    'timestamp': '2025-06-09T00:00:00',
#    'smart_tags': {'industries': ['Media']},
#    'highlights': []},
#   {'id': 'DL-d5c1b457b8e0448d43bf6c642ccfdd29',
#    'title': 'What to know about the Los Angeles immigration protests after citywide ICE operations',
#    'url': 'https://www.cbsnews.com/texas/news/california-los-angeles-immigration-protests-trump/',
#    'summary': 'a protest was planned for 2 p.m. Pacific Time outside Los Angeles City Hall. Protests continued into the evening, with several hundred demonstrators gathered near a doughnut shop. ICE officers executed search warrants at multiple locations in downtown Los Angeles.',
#    'score': 192.57867,
#    'timestamp': '2025-06-07T22:26:00',
#    'smart_tags': {'industries': ['Legal', 'Media']},
#    'highlights': ['President Trump signed a memo Saturday ordering the deployment of at least 2,000 National Guard troops to Los Angeles County, after clashes between immigration authorities and demonstrators in the cities of Paramount and neighboring Compton, where a car',
#     'A car burns during a protest in Compton, Calif., Saturday, June 7, 2025, after federal immigration authorities conducted operations. Eric Thayer / AP\nHow did the Los Angeles protests start?',
#     "Protesters taunt Los Angeles County Sheriff's deputies on Hunsaker Ave. on June 7, 2025 in Los Angeles, California."]},
#   {'id': 'DL-e3741d1e949cbd47a3f1aa97044218b9',
#    'title': "Los Angeles riots and police careers | Marines in action Newsom vs. Trump | He's a dictator",
#    'url': 'https://www.zazoom.it/2025-06-10/los-angeles-scontri-e-cariche-della-polizia-i-marines-in-campo-newsom-contro-trump-e-un-dittatore/17158066/',
#    'summary': 'The Trump presidency is announcing the deployment of 700 Marines to Los Angeles. It triggered the reaction of California Governor Gavin Newsom. The situation remains critical, with an uncertain future that requires attention and reflection.',
#    'score': 192.34119,
#    'timestamp': '2025-06-10T04:46:48',
#    'smart_tags': {'industries': ['Media']},
#    'highlights': ['Los Angeles riots and police careers | Marines in action Newsom vs.',
#     "As Elon Musk revisits Trump's and Jd Vance's protest posts on X, perhaps seeking a rapprochement with the administration. ⇑ Read on Open.online This news item talks about: Angeles Marines Newsom Trump Newsom, 'Great Shipment of Marines to Los Angeles'",
#     'Newsom, "Great Shipment of Marines to Los Angeles" -- "Great": so California Governor Gavin Newsom has defined Donald Trump\'s decision to send Marines to Los Angeles to protest the raids...']},
#   {'id': 'DL-3fb392049e5a3a6906b15da50c3f6a23',
#    'title': 'Keys to Understanding Mass Protests Against Migrant Riots in Los Angeles',
#    'url': 'https://www.elheraldo.co/mundo/2025/06/10/las-claves-para-entender-las-masivas-protestas-contra-las-redadas-migratorias-en-los-angeles/',
#    'summary': 'Los Angeles came under fire Monday on the fourth day of massive protests by hundreds of people over raids on undocumented immigrants ordered by US President Donald Trump. In response, a crowd demonstrated against these arrests, prompting Trump to order the deployment of more than 2,000 National Guard soldiers to repel the protests and guard the federal immigration building. This time was the first in 60 years to be deployed without the prior authorization of the governor of the state in question.',
#    'score': 192.26422,
#    'timestamp': '2025-06-10T02:16:19',
#    'smart_tags': {'industries': ['Media']},
#    'highlights': ['The city of Los Angeles came under fire Monday on the fourth day of massive protests by hundreds of people over raids on undocumented immigrants ordered by US President Donald Trump and his decision to deploy soldiers.',
#     'The origin of the protests The outbreak of unrest in Los Angeles began last Friday when the Immigration and Customs Service (ICE) carried out several raids at various points in Los Angeles that led to the arrest of at least 44 people in the Westlake district',
#     'Far from over, protests against Trump’s deportations from Los Angeles have spread over the weekend to other parts of California, such as San Francisco, where more than 150 people were arrested Sunday night after demonstrating against the ICE.']},
#   {'id': 'DL-8e207a731b305b6761aa398ff5fc26d0',
#    'title': 'CT protesters gather in solidarity with Los Angeles demonstrators over immigration raids',
#    'url': 'https://www.wshu.org/2025-06-09/ct-protests-la-immigration-raids-meriden-california',
#    'summary': "Rallies took place at the state Capitol and outside the Immigration and Customs Enforcement field office in Hartford. Connecticut organizers are calling for an end to “brutal ICE raids that are terrorizing immigrant workers and their communities.” They’re also demanding an end of the Trump administration's deployment of the National Guard in California in response to the protests.",
#    'score': 189.48157,
#    'timestamp': '2025-06-09T15:05:34',
#    'highlights': ['Protesters gathered in Connecticut Monday in solidarity with the ongoing demonstrations in Los Angeles over federal immigration raids.',
#     "They’re also demanding an end to the Trump administration's deployment of the National Guard in California in response to the protests and that David Huerta, a California union president who was detained during ICE raids, be freed.",
#     'Protests broke out Friday in Los Angeles after a series of immigration raids.\nRoughly 100 people gathered outside the state Capitol building Monday morning, many holding signs reading “FREE DAVID NOW” with images of Huerta.']},
#   {'id': 'DL-582725b0caa9ac3488165ec82487b1f7',
#    'title': 'Suspect who threw cinderblocks at ICE vehicles during Los Angeles riots has been identified',
#    'url': 'https://www.washingtonexaminer.com/news/3436440/suspect-threw-cinderblocks-ice-vehicles/',
#    'summary': "Attorney General Pam Bondi announced the news about identifying the suspect during an interview with Fox News host Sean Hannity. Recommended Stories Bondi insists US has jurisdiction over California when asked about supremacy clause in LA riots LAPD chief says department not notified of Marine arrival, could present 'significant' challenges Trump says he hopes allegations Elon Musk brought drugs into White House aren't true.",
#    'score': 187.42468,
#    'timestamp': '2025-06-10T09:16:02+00:00',
#    'highlights': []},
#   {'id': 'DL-9702332e7373b5c44ea618822490739f',
#    'title': 'Photos: Riots in Los Angeles after immigration raids',
#    'url': 'https://www.telemundolasvegas.com/noticias/eeuu/fotos-disturbios-en-los-angeles-tras-redadas-de-inmigracion/2402427/',
#    'summary': 'A car was set on fire at an intersection in Compton on Saturday. Keep up to date with local news and weather. Subscribe to our free newsletters here.',
#    'score': 185.36403,
#    'timestamp': '2025-06-08T07:38:53',
#    'smart_tags': {'industries': ['Media']},
#    'highlights': ['On Saturday, protesters and federal and local law enforcement officers clashed after immigration operations were conducted throughout the Los Angeles area.',
#     'A car was set on fire at an intersection in Compton on Saturday during a demonstration against the Immigration and Customs Control Service (ICE). Keep up to date with local news and weather. Subscribe to our free newsletters here.']},
#   {'id': 'DL-84406aabbb7fc3c4a36e90725848723e',
#    'title': 'Riots broke out in Los Angeles',
#    'url': 'https://www.gazeta.ru/social/news/2025/06/09/25995836.shtml',
#    'summary': 'a raid by the U.S. Immigration and Customs Police (ICE) turned into clashes with protesters. Representatives of the White House viewed the protests in Los Angeles as a "riot against the law"',
#    'score': 181.33742,
#    'timestamp': '2025-06-09T00:00:00',
#    'smart_tags': {'industries': ['Media']},
#    'highlights': ['Immigration and Customs Police (ICE) to identify illegal migrants in downtown Los Angeles turned into clashes with protesters. Representatives of the White House viewed the protests in Los Angeles as a "riot against the law". U.S.',
#     'President Donald Trump has accused California Governor Gavin Newsom and Los Angeles Mayor Karen Bass of failing to control the situation.',
#     'Newsom, in turn, called the U.S. president\'s decision to send 2,000 National Guard fighters to Los Angeles to disperse the protests "intentional incitement". Kamala Harris spoke about the riots in Los Angeles.']},
#   {'id': 'DL-e4a191806f954ba60f016be42b0d33dc',
#    'title': '"Get the Trumps!!!" Trump calls for tough measures against Los Angeles protesters',
#    'url': 'https://hotnews.ro/aduceti-trupele-trump-cere-masuri-dure-impotriva-protestatarilor-din-los-angeles-1997666',
#    'summary': 'Donald Trump asks the Los Angeles police chief to intervene. Tens of protesters took to the streets of downtown Los Angeles on Sunday evening. Donald Trump reacted and urged McDonnell to "bring the troops"',
#    'score': 180.86742,
#    'timestamp': '2025-06-09T08:31:00+00:00',
#    'smart_tags': {'industries': ['Media']},
#    'highlights': ["Donald Trump has asked the Los Angeles police chief to intervene after Sunday's scenes of violence between demonstrators dissatisfied with immigration raids and law enforcement, according to CNN.",
#     "Tens of protesters took to the streets of downtown Los Angeles on Sunday evening, a day after the US President ordered California's National Guard to intervene in Los Angeles.",
#     'Asked at a news conference Sunday evening if Los Angeles needs the National Guard, Los Angeles Police Department head Jim McDonnell responded, "Given what happened tonight, the situation is out of control."']},
#   {'id': 'DL-9c70349e86c342057f31e8a072e8c11d',
#    'title': 'Migrant arrests in Los Angeles lead to riots',
#    'url': 'https://www.tagesspiegel.de/internationales/terror-in-unseren-gemeinden-festnahmen-von-migranten-in-los-angeles-fuhren-zu-ausschreitungen-13820323.html',
#    'summary': 'In Los Angeles, raids by masked and armed officials have sparked angry protests against migrants. On Friday (local time), angry demonstrators chased an Immigration Department convoy in the US metropolitan area. Mayor Karen Bass stated that the martial actions of the officials cause "terror in our communities"',
#    'score': 180.7651,
#    'timestamp': '2025-06-07T15:56:17+00:00',
#    'highlights': []},
#   {'id': 'DL-19ac566c7a5dc8d6fa7335e640bc0cc4',
#    'title': "Los Angeles Mayor Bass calls on protesters to demonstrate 'peacefully'",
#    'url': 'https://www.msnbc.com/msnbc/watch/los-angeles-mayor-bass-speaks-amid-anti-ice-protests-241148485625',
#    'summary': "Los Angeles Mayor Bass calls on protesters to demonstrate 'peacefully' 02:36 UP NEXT Congressman demanding transparency from DHS & ICE in Los Angeles 08:19 Anti-ICE protests stop traffic on California's 101 Freeway 08:53 Congressman slams Trump administration for how it handled the case of Kilmar Abrego Garcia 05:37 Strategists say President Trump is sending National Guard to Los Angeles to make a spectacle 06:15 Trump on ICE raid protest",
#    'score': 180.53891,
#    'timestamp': '2025-06-09T01:15:41+00:00',
#    'smart_tags': {'signals': ['Leadership Mention'], 'industries': ['Media']},
#    'highlights': ["Authorities fire projectiles amid anti-ICE protests\n05:08\nNow Playing\nLos Angeles Mayor Bass calls on protesters to demonstrate 'peacefully'\n02:36\nUP NEXT\nCongressman demanding transparency from DHS & ICE in Los Angeles\n08:19\nAnti-ICE protests stop traffic",
#     "Kilmar Abrego Garcia's return to U.S. raises questions about Trump deportation agenda\n05:39\nLos Angeles protests erupt over 'worst fear' ICE raids\n04:53\nImmigration expert: Trump admin ‘trying to reverse engineer' Kilmar Abrego Garcia case\n10:24\nBREAKING",
#     ": Kilmar Abrego Garcia charged with two federal counts\n10:52\n‘Menacing’: Hayes sounds alarm on rise of ‘secret police’ under Trump\n05:50\nmsnbc\nLos Angeles Mayor Bass calls on protesters to demonstrate 'peacefully'\nShare this -\nLos Angeles Mayor Karen"]},
#   {'id': 'DL-9e9f470821621660bd15b5913583bcf5',
#    'title': 'Los Angeles protests against immigration policy',
#    'url': 'https://24tv.ua/ru/los-andzheles-protesty-protiv-migracionnoj-politiki-vse-chto_n2842238',
#    'summary': 'Australian journalist Lauren Thomasi was injured by a rubber bullet while covering the protests in Los Angeles. The Australian Ministry of Foreign Affairs and Trade condemned the attack and called for the safety of journalists. In California, the flag of the Soviet Union was observed during protests against immigration raids. This caused a resonance in the network.',
#    'score': 180.38441,
#    'timestamp': '2025-06-09T13:53:34',
#    'highlights': ['President even sent National Guard fighters to Los Angeles to stop protests against immigration policies. The next protest in the United States is not going quietly.',
#     'All that is known about the situation in Los Angeles as of now, Channel 24 collected in the material. Australian journalist Lauren Thomasi was injured by a rubber bullet while covering the protests in Los Angeles.',
#     'The mayor of Los Angeles denied the existence of National Guard fighters Local authorities stated that the protests were responded to by the police, not the National Guard.']},
#   {'id': 'DL-dcf26f10f2e22e67332b7f7a5bfe6661',
#    'title': 'China Warns US Citizens About Los Angeles Protests',
#    'url': 'https://www.haberler.com/guncel/cin-abd-deki-vatandaslarini-los-angeles-taki-protestolar-konusunda-uyardi-18725735-haberi/',
#    'summary': 'Chinese Embassy in Los Angeles issued a security warning. Citizens were asked to closely follow official announcements and media reports. The Trump administration issued harsh statements during anti-ICE protests.',
#    'score': 178.67725,
#    'timestamp': '2025-06-09T14:01:09',
#    'smart_tags': {'industries': ['Media']},
#    'highlights': ['China has warned US citizens to stay away from protests in Los Angeles in support of irregular immigrants and to be careful about their safety.',
#     'Anti-ICE protests in Los Angeles As demonstrations continued in the US city of Los Angeles in support of irregular immigrants detained by the Immigration and Customs Enforcement Agency (ICE), the Trump administration issued harsh statements.',
#     'US President Trump has announced he has deployed National Guard troops to control the situation in Los Angeles and has blamed Democratic leaders for the events in the region.']},
#   {'id': 'DL-46b345508cb685e85e41c260aff1fcd4',
#    'title': 'Trump blames "insurrectionists" for anti-immigration riots in Los Angeles',
#    'url': 'https://m.metrolibre.com/internacionales/trump-atribuye-disturbios-por-redadas-antiinmigracion-en-los-angeles-a-insurrectos-BE13531990',
#    'summary': '"The people causing the problems are professional agitators and insurgents," the Republican president tells reporters at the White House. "They would receive a blow stronger than ever, and that lack of respect will not be tolerated," he says. The president "raised the flames and acted illegally by mobilizing the National Guard" without consulting local authorities.',
#    'score': 178.4161,
#    'timestamp': '2025-06-09T16:04:00',
#    'smart_tags': {'industries': ['Legal', 'Media']},
#    'highlights': ['US President Donald Trump accused demonstrators in Los Angeles of insurrection Monday and threatened more force after a weekend of riots sparked by migrant raids.',
#     "Los Angeles police were monitoring the intersection of streets and downtown, which was declared a no-go area after Sunday's clashes. Aerial images broadcast on ABC7 showed some clashes with small groups of demonstrators.",
#     'At least 56 people were arrested in two days in Los Angeles and five officers were slightly injured, Los Angeles Police Department officials said. Around 60 people were arrested in protests in San Francisco.']},
#   {'id': 'DL-634d86e2973ccb70b016e6a90ad3acf4',
#    'title': 'Los Angeles protesters light Waymo cabs on fire',
#    'url': 'https://www.motorbiscuit.com/los-angeles-protesters-waymo-fire/',
#    'summary': 'Los Angeles, California, is dealing with some demonstrations and protesters. Most recently, the president has ordered the deployment of National Guard troops to the City of Angels to respond to acts of vandalism. The cabs look suspiciously like Jaguar I-PACE EVs in science fiction cosplay, devoid of drivers.',
#    'score': 178.11739,
#    'timestamp': '2025-06-10T07:45:05+00:00',
#    'smart_tags': {'industries': ['Hospitality and Travel']},
#    'highlights': ['Los Angeles, California, is dealing with some demonstrations and protesters as the Trump administration targets people in the city with ICE raids.',
#     'First responders warned Los Angeles residents to steer clear after protesters lit Waymo cabs on fire, releasing toxic gases\nLos Angeles is one of a handful of cities with Waymo self-driving taxi cabs.',
#     'Fast forward to this last weekend, and five of the autonomous taxis were targets for Los Angeles protesters seeking to demonstrate against the ICE raids in the city. The five Waymo cabs were queued up on Los Angeles Street near Acradia Street.']},
#   {'id': 'DL-36905af69d64c0ce860cba8e6c74432e',
#    'title': 'Los Angeles immigration protest clashes: What’s the latest and what’s next?',
#    'url': 'https://www.aljazeera.com/news/2025/6/9/third-night-of-los-angeles-clashes-whats-the-latest-and-whats-next',
#    'summary': 'Los Angeles has witnessed a third night of protests against the immigration crackdown by United States President Donald Trump’s administration. The Trump administration has indicated that it might send US marines in to help quell the protests. That scenario would mirror the events of 1992 when marines were deployed alongside the national guard for law enforcement in Los Angeles during riots that followed the acquittal of four policemen filmed beating Rodney King.',
#    'score': 175.18102,
#    'timestamp': '2025-06-09T12:49:33+00:00',
#    'smart_tags': {'industries': ['Media']},
#    'highlights': ['Los Angeles has witnessed a third night of protests against the immigration crackdown by United States President Donald Trump’s administration.',
#     'The protests sprung up as a response to these operations. Crowds of demonstrators gathered outside a facility where some of the detainees were believed to be held.\nWhere are the Los Angeles protests?',
#     'The Trump administration’s response to the protests in Los Angeles has drawn parallels with the riots that engulfed America’s second most populous city in 1992.']},
#   {'id': 'DL-52b57b8a5db908ae057fd9453093b1ea',
#    'title': 'Trump blames the "radical left" for the riots in Los Angeles',
#    'url': 'https://www.informador.mx/internacional/Trump-responsabiliza-a-la-izquierda-radical-de-los-disturbios-de-Los-Angeles-20250608-0055.html',
#    'summary': '"This protests by the Radical Left, for instigators and often paid troublemakers, will not be tolerated," Trump says. "I don\'t think it\'s necessary because I trust the Los Angeles Police Department and other law enforcement agencies in Los Angeles can handle things," the mayor tells ABC this Sunday. On Saturday, demonstrations concentrated in Paramount, where more than 50 federal vehicles conducted a migration operation.',
#    'score': 173.49722,
#    'timestamp': '2025-06-08T09:51:35',
#    'smart_tags': {'industries': ['Media']},
#    'highlights': ['As Los Angeles faces its third consecutive day of clashes between protesters and authorities over mass immigration raids, US President Donald Trump blamed the "radical left" behind the riots on Sunday.']},
#   {'id': 'DL-164fd3a18488526e27089f5d4b5d5499',
#    'title': 'Trump sends Marines, National Guard reinforcements to fight riots in Los Angeles',
#    'url': 'https://jauns.lv/raksts/arzemes/658688-tramps-nekartibu-apspiesanai-uz-losandzelosu-nosuta-juras-kajniekus-un-nacionalas-gvardes-papildspekus',
#    'summary': "US President Donald Trump's administration said on Monday that 700 Marines and 2,000 National Guard troops would be sent to Los Angeles to suppress the riots. On Sunday, about 300 of them took up positions to protect federal buildings and officials. The Marines will arrive in Los Angeles from Camp Pendleton, California.",
#    'score': 173.35075,
#    'timestamp': '2025-06-10T04:20:16+00:00',
#    'smart_tags': {'industries': ['Aerospace and Defense']},
#    'highlights': ['photo: ZUMAPRESS.com Trump sends Marines and National Guard reinforcements to fight riots in Los Angeles.',
#     'Trump to send troops to fight riots in Los Angeles As early as Saturday, Trump mobilized 2,000 National Guard troops and sent them to Los Angeles. On Sunday, about 300 of them took up positions to protect federal buildings and officials.',
#     'The riots in Los Angeles began with protests against the actions of the immigration services, which detained dozens of illegal immigrants and members of gangs.']},
#   {'id': 'DL-9088dc9f672c9b3ba10106e5dcd02c56',
#    'title': 'Riot Police, Anti-ICE Protesters Square Off In Los Angeles After Raids',
#    'url': 'https://www.ndtv.com/world-news/riot-police-anti-ice-protesters-square-off-in-los-angeles-after-raids-8613237',
#    'summary': 'Protests erupted in downtown Los Angeles following federal immigration raids. Officers declared an unlawful assembly as protesters clashed with police. Police responded by firing volleys of tear gas and pepper spray.',
#    'score': 171.61514,
# ...
#    'score': 132.8628,
#    'timestamp': '2025-06-09T00:44:00+00:00',
#    'highlights': ['Home tv forum Programs The news 1800 Demonstrators Shooting Vehicle During Downtown Los Angeles Protests Demonstrators Shooting Vehicle During Downtown Los Angeles Protests The protests in downtown Los Angeles are escalating: demonstrators set fire to',
#     'Demonstrations Late Hour Migration COMPARE: REPRODUCING Demonstrators Queman Vehículo During Protests in the Center of Los Angeles N+ FORO Third Day of Protests in Los Angeles: Demonstrators Queman Vehículos and Increases Tension N+ FORO Six Electric',
#     'Autonomous Vehicles Fired During Protests in Los Angeles N+ FORO This Is How Protests in Los Angeles Come From The Air: Police Attempt to Deploy Highway 101 N+ FORO Limpian Beaches in Campeche to Protect Marina Tortugas Anidación N+ FORO Robo Registers']},
#   {'id': 'DL-d47e55d4c8a2e31d422fa756857804f7',
#    'title': "Korean Americans in Los Angeles decry Trump Jr. for 'Rooftop Koreans' post",
#    'url': 'https://koreajoongangdaily.joins.com/news/2025-06-10/world/world/Korean-Americans-in-Los-Angeles-decry-Trump-Jr-for-Rooftop-Koreans-post/2326432',
#    'summary': "Korean Americans in Los Angeles condemn Donald Trump Jr. for invoking trauma of the 1992 Los Angeles riots by posting a photo of an armed Korean American during the unrest. The Korean American Federation of Los Angeles (Kafla) said Donald Trump's post mocking the current unrest by referencing the ‘rooftop Koreans’ from 33 years ago.",
#    'score': 131.63065,
#    'timestamp': '2025-06-10T10:28:54',
#    'smart_tags': {'industries': ['Media']},
#    'highlights': ["Korean Americans in Los Angeles have denounced President Donald Trump's oldest son, Donald Trump Jr., for making light of trauma triggered by the ongoing protests against immigration raids.The Korean American Federation of Los Angeles (Kafla) condemned",
#     'Trump Jr. for invoking the trauma of the 1992 Los Angeles riots by posting a photo of an armed Korean American during the unrest, writing "Make Rooftop Koreans Great Again!"',
#     'Gavin Newsom and Los Angeles Mayor Karen Bass both strongly opposed the deployment of the National Guard, arguing that it would provoke protesters and escalate tensions.Kafla also condemned the federal government for conducting raids without due process']},
#   {'id': 'DL-17eee7165f9471e59d72f73bb1ce6f4f',
#    'title': 'Riots in Los Angeles and the National Guard. What does Trump want to gain politically in California?',
#    'url': 'https://wiadomosci.radiozet.pl/news/zamieszki-w-los-angeles-i-gwardia-narodowa-co-trump-chce-ugrac-politycznie-w-kalifornii',
#    'summary': 'Donald Trump sent the National Guard to Los Angeles, explaining the decision to restore order. For several days on the streets of the “City of Angels” there are riots, which broke out after arrests of illegal immigrants. In doing so, Trump ignored California Governor Gavin Newsom.',
#    'score': 130.34993,
#    'timestamp': '2025-06-10T08:29:00+00:00',
#    'highlights': ['Protests in Los Angeles. “The situation could hurt Trump” On Sunday afternoon, protesters gathered outside an arrest in Los Angeles and chanted “Be ashamed” to the National Guard, which has formed a cordon around the federal building.',
#     'According to Professor Płudowski, the US president may use the riots in Los Angeles for other purposes.',
#     '. - Trump consciously uses the riots in Los Angeles to divert public attention from the conflict with Elon Musk and his accusations against the US president - says Płudowski.']},
#   {'id': 'DL-46c2c905df1c3e8fcf650e48e734d331',
#    'title': 'Border protests in Los Angeles on Day 3: demonstrations intensify',
#    'url': 'https://www.birgun.net/haber/los-angeles-taki-sinir-protestolari-3-gununde-gosteriler-siddetleniyor-629428',
#    'summary': 'Demonstrators and security forces continue to face each other during three days of border protests in Los Angeles. Local security forces, as well as National Guards, have been deployed in certain parts of the city. Los Angeles Police Department announced that unauthorised gatherings would be considered "illegal"',
#    'score': 129.89606,
#    'timestamp': '2025-06-09T04:38:00+00:00',
#    'smart_tags': {'industries': ['Media']},
#    'highlights': ['The Los Angeles Police Department (LAPD) announced that unauthorised gatherings would be considered "illegal" and that the demonstrators would be detained.',
#     'Several demonstrators were detained during the ongoing anti-ICE protests in Los Angeles, with occasional clashes between security forces and protesters.',
#     'US President Trump has announced he has deployed National Guard troops to control the situation in Los Angeles and has blamed Democratic leaders for the events in the region.']},
#   {'id': 'DL-bd0d7c23f44a738a98f4901f8645c168',
#    'title': 'Trump would activate little-used law to detain immigrants in any US state after riots in Los Angeles',
#    'url': 'https://larepublica.pe/mundo/2025/06/08/donald-trump-activaria-ley-olvidada-para-detener-inmigrantes-en-cualquier-estado-de-estados-unidos-tras-disturbios-en-los-angeles-lrtmus-174656',
#    'summary': "Trump’s government is assessing the possibility of activating an underused law that would allow it to detain, arrest and deport undocumented people. It would be the first time in six decades that a federal president would mobilize the National Guard in different states without the consent of state authorities. Governor Gavin Newsom and Mayor Karen Bass rejected the measure, believing that the federal government's intervention intensified the tension.",
#    'score': 129.22482,
#    'timestamp': '2025-06-08T20:41:13+00:00',
#    'smart_tags': {'signals': ['Regulatory'], 'industries': ['Legal']},
#    'highlights': ['Following a day in which 2,000 National Guard troops were deployed in Los Angeles to deal with immigrant protests against the Immigration and Customs Control Service (ICE), Donald Trump’s government is assessing the possibility of activating an underused',
#     'YOU CAN VIEW: Airplane with at least 16 passengers crashes in Tennessee: number of deaths still unconfirmed Migrant protests in Los Angeles The protests began after a series of raids by ICE agents in Paramount, California, where several immigrants were',
#     'These actions generated mobilization in various areas of Los Angeles, some of which became violent, with fires and clashes with the police, local media reported.']},
#   {'id': 'DL-2a6a6c7b97e3da1836ba716112ffd972',
#    'title': 'Trump says it would be ‘great’ if ICE arrested Gavin Newsom amid Los Angeles protests',
#    'url': 'https://www.wbtv.com/video/2025/06/09/trump-says-it-would-be-great-if-ice-arrested-gavin-newsom-amid-los-angeles-protests/',
#    'summary': "Thousands of protesters took to the streets in response to Trump's deployment of the National Guard. 4 of accused shooters in Catawba County mass shooting face additional 10 charges.",
#    'score': 128.88057,
#    'timestamp': '2025-06-09T21:16:00+00:00',
#    'smart_tags': {'signals': ['Leadership Mention'],
#     'industries': ['Legal', 'Media']},
#    'highlights': ["(CA DOJ)\nAerial video shows protests against ICE raids in LA\nUpdated: 53 minutes ago\n|\nThousands of protesters took to the streets in Los Angeles in response to Trump's deployment of the National Guard."]},
#   {'id': 'DL-957a536298f36bc0b989db9e7b7e89ae',
#    'title': 'Trump deploys 2,000 National Guard members after Los Angeles immigration protests',
#    'url': 'https://abc13.com/post/protests-erupt-immigration-customs-enforcement-raids-los-angeles-california/16690197/',
#    'summary': 'President Donald Trump signs memorandum "deploying 2,000 National Guardsmen to address the lawlessness" protests in Los Angeles over immigration enforcement operations have resulted in some clashes between demonstrators and authorities. California Gov. Gavin Newsom says the federal government is moving to "take over the California National Guard"',
#    'score': 128.75465,
#    'timestamp': '2025-06-08T04:00:55+00:00',
#    'smart_tags': {'signals': ['Hiring'],
#     'industries': ['Aerospace and Defense']},
#    'highlights': ['LOS ANGELES -- The Trump administration is deploying the California National Guard in response to protests in Los Angeles over immigration enforcement operations that have resulted in some clashes between demonstrators and authorities, the White House',
#     'Bass told ABC Los Angeles station KABC that neither she nor the Los Angeles Police Department were aware that the ICE raids were going to happen.',
#     'Shortly after 7 p.m. the Los Angeles Police Department declared an unlawful assembly, warning protesters they risked being arrested if they remained in the area. LAPD officers were seen lining the streets near the federal building, KABC reported.']},
#   {'id': 'DL-7f7c0b545efb3f88ac8d962199cbf652',
#    'title': 'National Guard arrives in Los Angeles after tense protests over Trump immigration enforcement',
#    'url': 'https://www.cbsnews.com/losangeles/video/national-guard-arrives-in-los-angeles-after-tense-protests-over-trump-immigration-enforcement/',
#    'summary': 'National Guard arrives in Los Angeles after tense protests over Trump immigration enforcement Troops with the National Guard arrived in Los Angeles early Sunday morning after intense protests about the Trump administrations immigration enforcement rocked the region in recent days. Alys Martinez reports.',
#    'score': 128.3217,
#    'timestamp': '2025-06-08T07:16:00',
#    'smart_tags': {'industries': ['Aerospace and Defense']},
#    'highlights': ['National Guard arrives in Los Angeles after tense protests over Trump immigration enforcement Troops with the National Guard arrived in Los Angeles early Sunday morning after intense protests about the Trump administrations immigration enforcement rocked']},
#   {'id': 'DL-8fb951baec332276b2142edd11980fc7',
#    'title': 'Immigration protests last overnight in Los Angeles following surprise ICE detainments',
#    'url': 'https://www.cbsnews.com/losangeles/video/immigration-protests-last-overnight-in-los-angeles-following-surprise-ice-detainments-1/',
#    'summary': 'Immigration protests last overnight in Los Angeles following surprise ICE detainments Protests lasted through the night in Los Angeles after ICE conducted surprise immigration operations on Friday. Alys Martinez reports.',
#    'score': 126.57784,
#    'timestamp': '2025-06-07T09:52:00',
#    'smart_tags': {'industries': ['Hospitality and Travel']},
#    'highlights': ['Immigration protests last overnight in Los Angeles following surprise ICE detainments Protests lasted through the night in Los Angeles after ICE conducted surprise immigration operations on Friday. Alys Martinez reports.']},
#   {'id': 'DL-2b30e9f31b5e8be88b64f83b93bd77b7',
#    'title': 'Trump sends National Guard to Los Angeles amid protests against immigration officers.',
#    'url': 'https://www.bol.uol.com.br/noticias/2025/06/08/trump-envia-guarda-nacional-para-los-angeles-em-meio-a-protestos-contra-agentes-de-imigracao.htm',
#    'summary': 'Secretary of Defense Pete Hegseth warns the Pentagon is ready to mobilize active-duty troops "if the violence continues" on Saturday, federal security agents clashed with protesters in the Paramount area of southeastern Los Angeles. A second protest in downtown Los Angeles on Saturday night drew about 60 people. The Governor of California calls the decision "proposally inflammatory"',
#    'score': 125.775764,
#    'timestamp': '2025-06-08T00:00:00',
#    'smart_tags': {'industries': ['Aerospace and Defense']},
#    'highlights': ['By Sandra Stojanovic and Omar Younis LOS ANGELES — U.S.',
#     'with protesters in the Paramount area of southeastern Los Angeles, where some protesters displayed Mexican flags.',
#     'A second protest in downtown Los Angeles on Saturday night drew about 60 people. Trump signed a presidential memo to send National Guard troops to "deal with the illegality that has been allowed," the White House said in a statement.']},
#   {'id': 'DL-2e9edef0da6ab7484d33539bed101c82',
#    'title': 'California Senators Call for Review of Arrest of Trade Union Leader During Riots in Los Angeles',
#    'url': 'https://www.infobae.com/america/agencias/2025/06/09/los-senadores-de-california-piden-revisar-la-detencion-de-un-lider-sindical-durante-las-redadas-en-los-angeles/',
#    'summary': 'Senators send letter to Department of Homeland Security and Department of Justice. "It is very worrying that an American citizen, a trade union leader and prominent member of the Los Angeles community are still being detained," senators say. Huerta was arrested and injured while attending a raid on undocumented immigrants.',
#    'score': 124.02312,
#    'timestamp': '2025-06-09T16:24:22+00:00',
#    'smart_tags': {'signals': ['Leadership Mention'], 'industries': ['Legal']},
#    'highlights': []},
#   {'id': 'DL-59c33f37f732de5b00ccbe9c66728dd1',
#    'title': 'Trump heads to Fort Bragg while facing criticism for deploying military at Los Angeles protests',
#    'url': 'https://www.ajc.com/news/2025/06/trump-heads-to-fort-bragg-while-facing-criticism-for-deploying-military-at-los-angeles-protests/',
#    'summary': 'Tanks and other vehicles will roll down city streets in a reminder of how the Republican president is reshaping the armed forces after returning to the White House this year. California sued Trump over the deployment, with the state attorney general arguing that the president had "trampled" the state\'s sovereignty.',
#    'score': 123.531204,
#    'timestamp': '2025-06-10T04:05:48',
#    'smart_tags': {'industries': ['Aerospace and Defense']},
#    'highlights': ['Trump, who sees the military as a critical tool for domestic goals, has used the recent protests in Los Angeles as an opportunity to deploy the National Guard and U.S. Marines to quell disturbances that began as protests over immigration raids.']},
#   {'id': 'DL-59029b17148d59eb50cf194bda93921a',
#    'title': 'National Guard called to Los Angeles amid anti-ICE protests',
#    'url': 'https://www.fox26houston.com/video/1654634',
#    'summary': 'National Guard troops clashed with protesters in Los Angeles Sunday, firing tear gas at a growing crowd downtown as protests against federal immigration sweeps continued for a third day.',
#    'score': 123.306244,
#    'timestamp': '2025-06-08T22:09:00+00:00',
#    'smart_tags': {'industries': ['Aerospace and Defense']},
#    'highlights': ['National Guard troops clashed with protesters in Los Angeles Sunday, firing tear gas at a growing crowd downtown as protests against federal immigration sweeps continued for a third day.']},
#   {'id': 'DL-97118126cb3cbef8f9cc5a4d58b28368',
#    'title': 'Trump heads to Fort Bragg while facing criticism for deploying military at Los Angeles protests',
#    'url': 'https://www.journal-news.com/nation-world/trump-heads-to-fort-bragg-while-facing-criticism-for-deploying-military-at-los-angeles-protests/PXOAYE5EVFECLGU3OYL4OTC65A/',
#    'summary': 'Defense Secretary Pete Hegseth and Army Secretary Dan Driscoll will also be at Tuesday\'s event. Tanks and other vehicles will roll down city streets in a reminder of how the Republican president is reshaping the armed forces. California sued Trump over the deployment, with the state attorney general arguing that the president had "trampled" the state\'s sovereignty.',
#    'score': 123.229126,
#    'timestamp': None,
#    'smart_tags': {'industries': ['Aerospace and Defense']},
#    'highlights': ['Trump, who sees the military as a critical tool for domestic goals, has used the recent protests in Los Angeles as an opportunity to deploy the National Guard and U.S. Marines to quell disturbances that began as protests over immigration raids.']}],
#  'query_details': {'query_text': 'what is happening with riots in Los Angeles?',
#   'rerank_method': None,
#   'diversity_ratio': 0,
#   'result_size': 100,
#   'timerange': '7d',
#   'include_highlights': True,
#   'include_smart_tags': True,
#   'ai_answer': None,
#   'cluster_results': None},
#  'count': 1580}

# %%
grouped_results = defaultdict(list)

for item in json_response['results']:

  if not item["timestamp"]:
    continue
  else:
    date = item["timestamp"].split("T")[0]

  grouped_results[date].append(item["title"])

grouped_results = dict(grouped_results)

sorted_group_counts = {date: len(grouped_results[date]) for date in sorted(grouped_results)}

#print(json.dumps(sorted_group_counts, indent=4))

print(json.dumps(grouped_results, indent=4))
# Out:
# {
#     "2025-06-10": [
#         "Los Angeles riots",
#         "Los Angeles riots and police careers | Marines in action Newsom vs. Trump | He's a dictator",
#         "Keys to Understanding Mass Protests Against Migrant Riots in Los Angeles",
#         "Suspect who threw cinderblocks at ICE vehicles during Los Angeles riots has been identified",
#         "Los Angeles protesters light Waymo cabs on fire",
#         "Trump sends Marines, National Guard reinforcements to fight riots in Los Angeles",
#         "Trump justifies troop deployment in Los Angeles over riots",
#         "Marines strengthen security in Los Angeles in the face of riots",
#         "In Australia condemned the incident during the riots in Los Angeles",
#         "Trump deploys another 2,000 National Guard for Los Angeles protests",
#         "Trump deploys thousands of Marines and guards in Los Angeles amid riots against riots",
#         "About 700 US Marines being mobilised in response to Los Angeles protests",
#         "About 700 US Marines being mobilised in response to Los Angeles protests",
#         "About 700 US Marines being mobilised in response to Los Angeles protests",
#         "Trump flexes strongman instincts with US military at Los Angeles protests",
#         "Korean Americans in Los Angeles decry Trump Jr. for 'Rooftop Koreans' post",
#         "Riots in Los Angeles and the National Guard. What does Trump want to gain politically in California?",
#         "Trump heads to Fort Bragg while facing criticism for deploying military at Los Angeles protests"
#     ],
#     "2025-06-09": [
#         "Los Angeles ICE Riots and the Constitution",
#         "After Trump deploys National Guard, Marines on standby as Los Angeles protests enter fourth day",
#         "Multiple Waymo vehicles set on fire during Los Angeles riots",
#         "Ogden residents demonstrate solidarity with Los Angeles protesters",
#         "The Masque and Trump Controversy and the Los Angeles Riots",
#         "Protests against riots in Los Angeles on the rise",
#         "Mask sided with Trump over Los Angeles riots after recent controversy",
#         "United States police shoot rubber bullet at Australian reporter during riots in Los Angeles",
#         "Migrants in Los Angeles protest ICE raids",
#         "Chaos intensifies: Riots in Los Angeles lead to looting (PHOTO)",
#         "Mexico's Prime Minister makes recommendations to Mexicans after 42 arrests in Los Angeles riots",
#         "TV reporter shot live on air during Los Angeles riots as report abruptly cut",
#         "VIDEOD \u27e9 Reporter hit by rubber bullet during live broadcast of Los Angeles riots",
#         "CT protesters gather in solidarity with Los Angeles demonstrators over immigration raids",
#         "Riots broke out in Los Angeles",
#         "\"Get the Trumps!!!\" Trump calls for tough measures against Los Angeles protesters",
#         "Los Angeles Mayor Bass calls on protesters to demonstrate 'peacefully'",
#         "Los Angeles protests against immigration policy",
#         "China Warns US Citizens About Los Angeles Protests",
#         "Trump blames \"insurrectionists\" for anti-immigration riots in Los Angeles",
#         "Los Angeles immigration protest clashes: What\u2019s the latest and what\u2019s next?",
#         ": Podcast Oceans Summit, Riots in Los Angeles and legendary Alcaraz: what does that mean on June 9th?",
#         "Elon Musk surprisingly defended Trump on the Los Angeles protests",
#         "Trump spoke out about the riots in Los Angeles and protested.",
#         "Riots in Los Angeles are gaining momentum, arrested dozens of people",
#         "Trump defends troop deployment, blames 'insurrectionists' for Los Angeles protests",
#         "Los Angeles protests live: LAPD calls for protesters to disperse as Trump says \u2018bring in the troops\u2019",
#         "Sheinbaum calls for \"respectful\" migration procedures after riots in Los Angeles",
#         "Riots in Los Angeles won\u2019t force Trump to stop deporting illegals",
#         "'They want this fight': How the White House views Los Angeles protests",
#         "Police clash with Los Angeles protesters as opposition to Trump intensifies",
#         "Australian Journalist Shot Live on Air During Los Angeles Protests",
#         "Los Angeles protests turn spotlight on California's ambitious governor Gavin Newsom",
#         "Reporter hit by nonlethal round during live report from Los Angeles protests",
#         "Trump administration mobilizing 2,000 more National Guard troops for Los Angeles protests",
#         "British photographer prevented from killing in Los Angeles protest by unsuitable bullet: urgent operations needed",
#         "Trump deploys 700 Marines in Los Angeles to protest raids",
#         "FBI searching for suspect who allegedly assaulted federal officer during anti-ICE riots in Los Angeles",
#         "Demonstrators Queman Veh\u00edculo During Protests in downtown Los Angeles",
#         "Border protests in Los Angeles on Day 3: demonstrations intensify",
#         "Trump says it would be \u2018great\u2019 if ICE arrested Gavin Newsom amid Los Angeles protests",
#         "California Senators Call for Review of Arrest of Trade Union Leader During Riots in Los Angeles"
#     ],
#     "2025-06-07": [
#         "Protests Against Immigration Officers Grow in Los Angeles Over Riots",
#         "Tens of migrants arrested in riots in Los Angeles",
#         "Migratory networks against Hispanics in Los Angeles spark protests and clashes",
#         "Riots in Los Angeles Raids by masked and armed officials against migrants trigger protests",
#         "What to know about the Los Angeles immigration protests after citywide ICE operations",
#         "Migrant arrests in Los Angeles lead to riots",
#         "Riot Police, Anti-ICE Protesters Square Off In Los Angeles After Raids",
#         "What to know about the Los Angeles immigration protests over ICE operations",
#         "Trump deploys National Guard after second day of Los Angeles immigration protests",
#         "Immigration protests last overnight in Los Angeles following surprise ICE detainments"
#     ],
#     "2025-06-08": [
#         "Anti-ICE Riot in Los Angeles",
#         "Los Angeles Trump protests | I won't let you hide in demonstrations in California",
#         "Photos: Riots in Los Angeles after immigration raids",
#         "Photos: Riots in Los Angeles after immigration raids",
#         "Trump blames the \"radical left\" for the riots in Los Angeles",
#         "Los Angeles Trump protests | I won't allow masks in demonstrations in California",
#         "Troops are being deployed in Los Angeles to suppress protests",
#         "Trump deploys National Guard as Los Angeles protests against immigration agents continue",
#         "Live blog: National Guard arrives in Los Angeles after protests over ICE arrests",
#         "Riots erupt in Los Angeles over the immigration crackdown.",
#         "Live blog: National Guard arrives in Los Angeles after protests over ICE arrests",
#         "Live blog: National Guard arrives in Los Angeles after protests over ICE arrests",
#         "Trump deploys National Guard as Los Angeles protests against immigration agents continue",
#         "Trump deploys National Guard over Los Angeles immigration protests",
#         "Trump blames \"radical left\" for instigating and financing Los Angeles protests",
#         "Sheinbaum urges U.S. not to treat migrants as criminals after riots in Los Angeles",
#         "Anti-ICE protests persist in Los Angeles despite National Guard deployment",
#         "Los Angeles protests over immigration raids led to clashes with police and federal action",
#         "Trump deploys National Guard in Los Angeles after immigration riots",
#         "Trump deploys National Guard in Los Angeles after immigration riots",
#         "Trump would activate little-used law to detain immigrants in any US state after riots in Los Angeles",
#         "Trump deploys 2,000 National Guard members after Los Angeles immigration protests",
#         "National Guard arrives in Los Angeles after tense protests over Trump immigration enforcement",
#         "Trump sends National Guard to Los Angeles amid protests against immigration officers.",
#         "National Guard called to Los Angeles amid anti-ICE protests"
#     ],
#     "2025-06-06": [
#         "Pussy Riot co-founder starts Los Angeles prison performance with existential scream",
#         "Trump sent the National Guard to Los Angeles amid protests"
#     ]
# }

# %%
from transformers import pipeline

pipe = pipeline("summarization", model="facebook/bart-large-cnn", max_length=30)

daily_summaries = []

query_results = json.dumps(grouped_results, indent=4)
#print(grouped_results)

for day in grouped_results:
  to_summarize = ""
  summaries = grouped_results[day] #['summary1', 'summary2'...]
  for summary in summaries:
    to_summarize += summary
  print(to_summarize)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu
# Los Angeles Consulting Group June Events 2025Big Bear eaglet update: Sunny returns home from her first flightCinespia’s big July line-up opens with ‘Top Gun’Meghan Markle to make major appearance within days at glitzy gala in LALos Angeles County celebrates Pride Month with raising of Progress Pride FlagDonald Trump inflates tariffs, global growth stagnatesThe BriefSchool aide arrested for possessing, distributing child pornJames Beard finalist for Outstanding Professional in Beverage ServiceDisney Lays Off Hundreds Across Film and TV Divisions Amid Ongoing Cost-Cutting PushWashington father wanted for murder after 3 daughters found dead: PoliceTrevor Bauer accuser ordered to pay $310KTechcombank Expands Overseas Talent Roadshow 2025 To Europe Following U.S. SuccessNvidia tops Microsoft, regains most valuable company title for first time since January
# European stocks mixed as trade tensions and U.S. economy remain in focusImpact on World Cup, OlympicsMillions of Californians who rely on Medi-Cal and In-Home Supportive Services could lose eligibilityWhat the Trump travel ban means for the 2026 World Cup and 2028 Olympic GamesWhat the Trump travel ban means for the 2026 World Cup and 2028 Olympic GamesWhat the Trump travel ban means for 2026 World Cup, 2028 OlympicsMan killed in shooting near school in East LATrade deficit fell by a record amount in April as demand dropped for imports
# Los Angeles immigration raid protests updateCelebrity breast cancer announcements highlight rising rates in young womenLive blog: National Guard arrives in Los Angeles after protests over ICE arrestsImmigration authorities extend activity in Los Angeles area amid street protestsFrom Juárez to the World: Pagano opens historic WWE-AAA event in Los AngelesLos Angeles ICE protests explained: What happened this weekend in Paramount, Compton and downtown LA?Media Panics About “Crime Waves” - But Downplays Crime Committed by CorporationsChaos erupts in the L.A. area following increased activity across the country by ICELive blog: National Guard arrives in Los Angeles after protests over ICE arrestsLive blog: National Guard arrives in Los Angeles after protests over ICE arrestsTrump would activate little-used law to detain immigrants in any US state after riots in Los AngelesTropical Storm Barbara forms off coast of southwest Mexico
# Techcombank Expands Overseas Talent Roadshow 2025 to Europe Following U.S. SuccessJAPAN HOUSE Los Angeles Announces June ProgrammingJAPAN HOUSE Los Angeles Announces June ProgrammingLong Beach and Inland Empire Job Corps centers closeTechcombank Expands Overseas Talent Roadshow 2025 to Europe Following U.S. SuccessWhere to watch Spain-France in Nations League semis: TV, stream
# Anti-ICE protesters arrested in Santa Ana2 dead in shooting on busy Las Vegas strip, police sayVideo: protests in Los Angeles - the latest newsWhat happened in Los Angeles with the protests against Trump’s measures?What is happening in Los Angeles is not law enforcement, it’s occupationIn addition, the Committee recommends that the State party take all appropriate measures, including legislation, to prohibit corporal punishment of children in the family, in schools and in institutions, and to ensure that corporal punishment is prohibited in all settings, including in the home.Photos: Protests continue for third day in Los AngelesKilmar Abrego Garcia Returned to United States; California Threatens to Sue Over National Guard Deployment; Interview With Los Angeles Mayor Karen Bass. Aired 11-11:30a ETWhat Americans think about Trump's deportation efforts, according to CBS News pollingTerreno Realty (TRNO) Acquires Los Angeles Industrial Property for $10M | TRNO Stock NewsTrump Administration Sends 700 Marines to Los AngelesMexican consulates in the US activate protocols to protect migrants from raids in Los AngelesTrump Deploys Marines To L.A.: What We KnowLos Angeles police arrest further 10 people on Sunday – as it happenedLos Angeles police arrest further 10 people on Sunday – as it happenedLos Angeles police arrest further 10 people on Sunday – as it happenedLos Angeles police arrest further 10 people on Sunday – as it happenedLos Angeles police arrest further 10 people on Sunday – as it happenedSungrow's PowerTitan 3.0: A Game-Changer in Energy Storage and a Strategic Investment PlayNational Guard only guarding LA's federal buildings, Bass saysMigration protests: 60 arrests in San Francisco and 27 in Los AngelesReporter hit as LA officers fire rubber bullets at protestersAfter Trump deploys National Guard, Marines on standby as Los Angeles protests enter fourth dayThe protests intensify in Los Angeles after Trump has deployed hundreds of troops of the National Guard | NewsMN weather: Monday forecast updateCalifornia: Secretary of Defense threatens to mobilize active-duty troops if violence continues.Trump Los Angeles Riots: National Guard Deployment?
# Immigration authorities extend activity in Los Angeles area amid street protestsU.S. immigration authorities extend activity in Los Angeles area amid street protestsLAX/Metro Transit Center Metro Station officially opens, connecting communities and providing faster and easier travel for angels and visitors USA - español Korea - 한국어 APAC - Traditional Chinese India - English USA - English MEXICO - Spanish USA - Français USA - Deutsch BRAZIL - Portuguese Japan - JapaneseAngelina Jolie and Brad Pitt's daughter drops her father's surnameUS Rep. Jimmy Gomez, immigration advocates demand transperancy from DHS and ICEDemocrats set out to study male voters with "Sam Project"
# ICE Activity in Los Angeles Fashion District Warned: Migrants Fear for their SafetyState Dept says current US visas from travel ban countries will not be revokedWhat the Trump travel ban means for the 2026 World Cup and 2028 Olympic GamesTrump banned travel from 12 countries, but included some exceptions to avoid legal battlesWhat Trump Travel Ban Means For 2026 World Cup And 2028 Olympic GamesWhat the Trump travel ban means for the 2026 World Cup and 2028 Olympic GamesWhat the Trump travel ban means for the 2026 World Cup and 2028 Olympic GamesHow does the US travel ban affect the 2026 World Cup and the 2028 Olympics? #7JunWhat does Trump’s migration veto mean for the 2026 World Cup and the 2028 Olympic Games?‘Hye Heart, Unbroken’: A Poetry Night of Remembrance Comes to GlendaleHeadliners announced for Sunday's free LA Pride Village concert in HollywoodFunctional Outcomes and Activity Levels in Patients After Internal Hemipelvectomy for Primary Sarcoma Involving the Bony PelvisCelebrating Cultural Diversity During Refugee Awareness Month
# Who is David Huerta, a Mexican trade union leader arrested and released during protests in Los Angeles?Newsom says state will sue after Trump administration activates 700 Marines in Los Angeles area amid ICE protestsAbout 700 US Marines being activated to respond to protests in Los AngelesEvents Donald Trump deploys thousands of troops to Los AngelesLA protests: California governor slams deployment of MarinesLA protests: US Northern Command activates a battalion of 700 MarinesNot to Suppress Riot: Trump Still Sends Marines to Burning Los AngelesTwo people smash van with skateboardsNewsom Suing Trump Over What Eisenhower, JFK and Bush Also Did with National GuardNewsom Suing Trump Over What Eisenhower, JFK and Bush Also Did with National GuardSharp criticism of US President Doechii condemns "reckless attacks" on protesters in L.A.Significant escalation: seafarers sent to Los Angeles

# %%
# summaries_to_summarize = []

# for day in grouped_results: #[list of strings]
#   summaries = grouped_results[day]
#   to_summarize = ""
#   for summary in summaries:
#     to_summarize += summary


#   """
#   for summary in summaries:
#     to_summarize += summary
#   print(to_summarize)
#   """
# print(to_summarize)
# Out:
# Swedish activist Greta Thunberg is attempting to break the Gaza blockade. The Madleen left Italy on June 1 with the aim of delivering aid. Aboard the boat are nationals of Germany, France, Brazil, Turkey, Sweden and Spain.Israel's defence minister vows to prevent aid boat carrying Greta Thunberg and other activists from reaching the Gaza Strip. The Madleen, operated by the Freedom Flotilla Coalition, departed Sicily on June 1 on a mission that aims to break the sea blockade of Gaza and deliver humanitarian aid.The Madleen is part of the Freedom Flotilla Coalition. There are 12 survivors on board, with the Dutchman as captain. "There is no reason for Israel to attack us," Greta Thunberg tells RTL News.Israeli forces stopped a Gaza-bound aid boat and detained Greta Thunberg and other activists. The Freedom Flotilla Coalition said the activists had been "kidnapped by Israeli forces" Israel's Foreign Ministry cast the voyage as a public relations stunt. All the passengers of the 'selfie yacht' are safe and unharmed.Israeli government vows to prevent aid boat carrying Greta Thunberg from reaching Gaza. The Climate activist joins aid ship sailing to Gaza aimed at breaking Israel's blockade. At least 31 Palestinians are killed while heading to a Gaza aid hub, officials say.Israel's government vows to prevent aid boat carrying Greta Thunberg and other activists from reaching the Gaza Strip. Defense Minister Israel Katz said that Israel wouldn’t allow anyone to break its naval blockade of the Palestinian territory. He said Israel would stop Hamas from importing arms. The Madleen is operated by the Freedom Flotilla Coalition.Israel vows to prevent aid boat carrying Greta Thunberg from reaching Gaza. Defense Minister Israel Katz said Israel wouldn't allow anyone to break its naval blockade of the Palestinian territory. The Madleen is operated by the Freedom Flotilla Coalition.Israel vows to prevent aid boat carrying Greta Thunberg from reaching Gaza. Defense Minister Israel Katz said Israel wouldn't allow anyone to break its naval blockade of the Palestinian territory. The Madleen is operated by the Freedom Flotilla Coalition.Israel's government vows to prevent aid boat carrying Greta Thunberg from reaching Gaza. Defense Minister Israel Katz said that Israel wouldn't allow anyone to break its naval blockade of the Palestinian territory. The Madleen is operated by the Freedom Flotilla Coalition.Israel's government vows to prevent aid boat carrying Greta Thunberg from reaching Gaza. Defense Minister Israel Katz said that Israel wouldn't allow anyone to break its naval blockade of the Palestinian territory. The Madleen is operated by the Freedom Flotilla Coalition.Israeli threats don't stop you Greta Thunberg appeals once again to justice, sailing to Gaza on a shipload of humanitarian aid. The Madleen's payload consists mostly of flour, rice and kits to make the water drinkable. Israeli Defense Minister, Israel Katz, sent a message to the activists, asking them to come back before the IDF was forced to intervene.TEL AVIV (Sputnik) – Israeli Defense Minister Israel Katz said on Sunday that he will not allow the humanitarian ship Madleen carrying Swedish climate activist Greta Thunberg to reach the coast of the Gaza Strip.
# Sputnik News
# South Africa Today – World NewsIsraeli Defence Minister Israel Katz ordered the army to prevent the arrival of a humanitarian ship. There are about 10 people on board, including activist Greta Thunberg and MEP Rima Hassan. On the Palestinian side, more than 54,772 people, mostly civilians, were killed in the campaign of Israeli military reprisals.Israel Katz says Israel will not allow anyone to break the naval blockade of Palestinian territory. Greta Thunberg is one of the 12 activists on board the Madleen, operated by the Freedom Flotilla Coalition. The ship departed Sicily last Sunday on a mission.Israel vows to prevent aid boat carrying Greta Thunberg from reaching Gaza. Defense Minister Israel Katz said Israel wouldn't allow anyone to break its naval blockade of the Palestinian territory. The Madleen is operated by the Freedom Flotilla Coalition. It departed Sicily last Sunday on a mission that aims to break the sea blocade and deliver humanitarian aid.Israel vows to prevent aid boat carrying Greta Thunberg from reaching Gaza. Defense Minister Israel Katz said Israel wouldn't allow anyone to break its naval blockade of the Palestinian territory. The Madleen is operated by the Freedom Flotilla Coalition. It departed Sicily last Sunday on a mission that aims to break the sea blocade and deliver humanitarian aid.Israel vows to prevent aid boat carrying Greta Thunberg and other activists from reaching the Gaza Strip. Defense Minister Israel Katz said that Israel wouldn't allow anyone to break its naval blockade of the Palestinian territory. The Madleen is operated by the Freedom Flotilla Coalition. It departed Sicily last Sunday on a mission that aims to break the sea blocade and deliver humanitarian aid.Israel's defense minister vows to prevent aid boat carrying Greta Thunberg from reaching Gaza. The Madleen is operated by the Freedom Flotilla Coalition. It departed Sicily last Sunday on a mission to break the sea blockade of Gaza and deliver humanitarian aid.The Israeli government promised on Sunday to stop a humanitarian aid boat carrying Greta Thunberg and other activists from reaching the Gaza Strip. The Defense Minister, Israel Katz, said that Israel would not allow anyone to break the naval blockade of Palestinian territory, which, in his view, is aimed at blocking the import of weapons by Hamas.Israeli Defence Minister Yoav Gallant ordered the army to prevent the arrival of the Madleen. On board were activists including Greta Thunberg and Rima Hassan. Israel says the maritime blockade is essential to prevent transfer of weapons to the Islamist militia.Israel's defense minister threatens to "use all necessary means" to prevent ship from reaching the Gaza Strip. A 22-year-old climate activist is one of a dozen activists on board the Madeleine that left Sicily last week on a mission to break the naval blockade of Israel.Climate activist Greta Thunberg is among 12 activists aboard the Madleen boat. The vessel departed Sicily last Sunday on a mission to break the sea blockade of Gaza and deliver humanitarian aid. Defense Minister Israel Katz said that Israel wouldn’t allow anyone to break its naval blocade.Israel's government vows to prevent aid boat carrying Greta Thunberg and other activists from reaching the Gaza Strip. Defense Minister Israel Katz said Israel wouldn't allow anyone to break its naval blockade of the Palestinian territory. He said it was aimed at preventing Hamas from importing arms.Israel's government vows to prevent aid boat carrying Greta Thunberg from reaching the Gaza Strip. Defense Minister Israel Katz said Israel wouldn't allow anyone to break its naval blockade of the Palestinian territory, which he said was aimed at preventing Hamas from importing arms. The Madleen, which is operated by the Freedom Flotilla Coalition, departed Sicily last Sunday.Israel intends to block access to Gaza by Madleen convoy carrying Swedish activist Greta Thunberg and 11 other activists. Israeli Defence Minister, Israe ...

# %%
# from transformers import pipeline

# summarizer = pipeline("summarization", model="facebook/bart-large-cnn", max_length=30)

# for day in grouped_results: #[list of strings]
#   print(day)
#   summaries = grouped_results[day]
#   to_summarize = ""
#   for summary in summaries:
#     to_summarize += summary
#   # print(to_summarize)
#   summary = summarizer(to_summarize, max_length=150, do_sample=False)
#   print(summary)

from transformers import pipeline

summarizer = pipeline("summarization", model="facebook/bart-large-cnn")

for day, summaries in grouped_results.items():
    print(day)
    to_summarize = " ".join(summaries)[:2024]  # Limit input size
    summary = summarizer(to_summarize, max_length=100, num_beams=2, do_sample=False)
    print(summary[0]["summary_text"])
# Out:
# Device set to use cpu
# 2025-06-10
# Trump deploys thousands of Marines and guards in Los Angeles amid riots against riots. About 700 US Marines being mobilised in response to Los Angeles protests. Trump flexes strongman instincts with US military at LA protests. Korean Americans decry Trump Jr. for 'Rooftop Koreans' post Riots.
# 2025-06-09
# Riots in Los Angeles are gaining momentum, arrested dozens of people. President Trump deploys National Guard, Marines on standby as Los Angeles protests enter fourth day. China Warns US Citizens About Los Angeles Protests. Elon Musk surprisingly defended Trump on the Los Angeles riots.
# 2025-06-07
# Protests Against Immigration Officers Grow in Los Angeles Over Riots Tens of migrants arrested in riots in Los Los Angeles Migratory networks against Hispanics in Los LA spark protests and clashes. Raids by masked and armed officials against migrants trigger protests in Los L.A. Migrant arrests in LA lead to riots.
# 2025-06-08
# Your max_length is set to 100, but your input_length is only 26. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=13)
# National Guard called to Los Angeles amid anti-ICE protests. Trump blames "radical left" for instigating and financing Los Angeles protests. Anti-ICE protesters persist in Los Angeles despite National Guard deployment. Trump would activate little-used law to detain immigrants in any US state after riots.
# 2025-06-06
# Pussy Riot co-founder starts Los Angeles prison performance with existential scream. Trump sent the National Guard to Los Angeles amid protests amid protests. Pussy Riot's Nadezhda Tolokonnikova: 'I am not a victim. I am a survivor'

# %%
json_response['results'][0]

# %%
df = pd.json_normalize(json_response['results'])

df.head()

# %% [markdown]
# ## Example Sentiment Analysis

# %%
## Clean data

def clean_text(text):
    """
    - Convert to lowercase
    - Remove URLs
    - Remove punctuation / non-alpha
    - Collapse multiple spaces
    """
    if not isinstance(text, str):
        return ""
    # Remove URLs (very basic)
    text = re.sub(r"http\S+|www\.\S+", "", text)
    # Lowercase
    text = text.lower()
    # Keep only letters and spaces
    text = re.sub(r"[^a-z\s]", " ", text)
    # Collapse multiple spaces
    text = re.sub(r"\s+", " ", text).strip()
    return text

df['clean_summary'] = df['summary'].apply(clean_text)

# %%
## Sentiment analysis example

sia = SentimentIntensityAnalyzer()

def get_sentiment_scores(text):
    """
    Returns a dict with these keys:
       - neg: negative sentiment score
       - neu: neutral score
       - pos: positive score
       - compound: normalized, weighted composite (-1 to +1)
    """
    return sia.polarity_scores(text)

# Apply to each summary
df['sentiment'] = df['clean_summary'].apply(get_sentiment_scores)

# Split into separate columns if you like
df['sent_neg'] = df['sentiment'].apply(lambda d: d['neg'])
df['sent_neu'] = df['sentiment'].apply(lambda d: d['neu'])
df['sent_pos'] = df['sentiment'].apply(lambda d: d['pos'])
df['sent_compound'] = df['sentiment'].apply(lambda d: d['compound'])

# Quick look at top 5 compound scores
print(df[['clean_summary', 'sent_compound']].sort_values(by='sent_compound', ascending=False).head())
print(df[['clean_summary', 'sent_compound']].sort_values(by='sent_compound').head())

# %%
# Find index of the most positive (max compound) and most negative (min compound) summaries
max_idx = df['sent_compound'].idxmax()
min_idx = df['sent_compound'].idxmin()

# Retrieve the scores
max_score = df.loc[max_idx, 'sent_compound']
min_score = df.loc[min_idx, 'sent_compound']

# Print the full clean summaries along with their sentiment scores
print("Most positive summary (compound = {:.3f}):\n".format(max_score))
print(df.loc[max_idx, 'clean_summary'])


print("\n\nMost negative summary (compound = {:.3f}):\n".format(min_score))
print(df.loc[min_idx, 'clean_summary'])

# %% [markdown]
# ## Project Ideas
#
# Feel free to use this code to start your own project, and here are some (Chat-GPT generated 😬) ideas for projects:
#
# * Real-Time Sentiment Pulse: Visualize sentiment trends over the past 24-48 hours for any keyword.
#
# * One-Click News Brief: Generate a 3-sentence summary of today's top articles on a given topic.
#
# * Bias/Slant Detector: Compare headlines from multiple outlets on the same event and label their bias.
#
# * Event Timeline Generator: Autofill a chronological list of key dates and summaries for any query.
#
# * Breaking News Alert Bot: Push a short alert whenever article volume spikes or sentiment turns extreme.
#
# * Multilingual Hashtag Trend Mapper: Show related hashtags and translations across different languages.
#
# * Rumor vs. Fact Checker: Verify a user-provided statement against recent reputable sources.
#
# * “What's Changed?” Comparator: Highlight how coverage of a topic has shifted from last month to last week.
#
# * Geo-Mood Map: Color-code countries by average sentiment or topic intensity on a query.
#
# * Voice-Activated News Q&A: Let users speak a question and hear back a 2–3 sentence summary of current events.

# %% [markdown]
# ## Dashboard libraries for Python
#
# https://shiny.posit.co/py/
#
# https://dash.plotly.com/
#
# https://streamlit.io/
